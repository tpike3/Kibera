# %%
import geopandas as gpd

# %%
shop_shp = "./KIANDA_shapefile/KIANDA_STRUCTURES/Population_2/kianda_structures_and_population_dataset.dbf"

shops = gpd.read_file(shop_shp)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
shops.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1510 entries, 0 to 1509
# Data columns (total 55 columns):
# MAT_WOO_D    1510 non-null float64
# FAM_S_D      1510 non-null float64
# RENT_STR     1510 non-null int64
# RENT_MEAN    1510 non-null int64
# BUSINESS     1510 non-null float64
# GEOMETRY     1510 non-null float64
# MAT_M_D      1510 non-null float64
# OWNER        1510 non-null float64
# RENT_MIN     1510 non-null float64
# WOMEN        1510 non-null float64
# WATER        1510 non-null float64
# VIL_CODE     1510 non-null object
# ELECT_D      1510 non-null float64
# MAT_IR_D     1510 non-null float64
# FAM_UP_D     1510 non-null float64
# ROOMS        1510 non-null float64
# SERV_H       1510 non-null float64
# BUSI_C       1510 non-null float64
# TOT_UNITS    1510 non-null float64
# EMPTY        1510 non-null float64
# HOUSEHOLD    1510 non-null float64
# MAT_M        1510 non-null float64
# SERVICE      1510 non-null float64
# ...

# %%
shops
# Out:
#       MAT_WOO_D  FAM_S_D  RENT_STR  RENT_MEAN  BUSINESS  GEOMETRY  MAT_M_D  \
# 0           0.0    0.000      1500        500       1.0       0.0    1.000
# 1           0.0    0.000         0          0       0.0       0.0    0.000
# 2           0.0    0.000         0          0       0.0       0.0    0.000
# 3           0.0    0.300     17000       1700       1.0       0.0    0.250
# 4           0.0    0.000     12000       4000       2.0       0.0    0.333
# 5           0.0    0.000         0          0       0.0       0.0    0.000
# 6           0.0    0.000      8400       2100       4.0       0.0    0.000
# 7           0.0    0.500      8400       1400       0.0       0.0    1.000
# 8           0.0    0.571      8400       1400       0.0       0.0    0.800
# 9           0.0    0.667      2800        700       0.0       0.0    1.000
# 10          0.0    0.333     10800       1350       0.0       0.0    1.000
# ...

# %%
type(shops["geometry"][0])
# Out:
# shapely.geometry.polygon.Polygon

# %%
for shape in shops["geometry"]:
    if type(shape) != "shapely.geometry.polygon.Polygon":
        print (type(shape))
# Out:
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# <class 'shapely.geometry.polygon.Polygon'>
# ...
