# %%
import pandas as pd
from IPython.display import display, HTML
from simpledbf import Dbf5

import numpy as np

dbf = Dbf5("C:\\Users\\ymamo\\Kibera\\KIANDA_shapefile\\KIANDA_STRUCTURES\\Population_2\\kianda_structures_and_population_dataset.dbf")

df = dbf.to_dataframe()
df1 = df[["POP_R", "WOMEN", "CHILD", "FAMILIES","WATER", "FAM_SP", "STR_CODE", "RENT_STR","ROOMS","ELECT", "TOILET","WATER", "BUSINESS" ]]
df2 = df[["RENT_STR","RENT_MIN", "RENT_MAX", "RENT_MEAN", "FAMILIES" ]]
df3 = df[["POP_R", "FAMILIES", "TOILET", "ELECT", "OWNER", "STR_CODE", "ROOMS"]]
df.head()
display(HTML(df3.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>POP_R</th>
#       <th>FAMILIES</th>
#       <th>TOILET</th>
#       <th>ELECT</th>
#       <th>OWNER</th>
#       <th>STR_CODE</th>
#       <th>ROOMS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>KIAS1S95S0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>KIAS0S0S0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>KIAS0S0S0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>29.0</td>
#       <td>10.0</td>
#       <td>6.0</td>
# ...

# %% [markdown]
# # Find orphanages

# %%
df_orp2 = df[(df["CHILD"]> 0) & (df["FAM_S"] > 0) & (df["FAM_SP"] == 0) & (df["FAM_UP"]==0) & (df["FAM_P"]==0) \
             & (df["FAM_C"]==0) & (df["CHILD_D"]> 0.7)]
display(HTML(df_orp2.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MAT_WOO_D</th>
#       <th>FAM_S_D</th>
#       <th>RENT_STR</th>
#       <th>RENT_MEAN</th>
#       <th>BUSINESS</th>
#       <th>GEOMETRY</th>
#       <th>MAT_M_D</th>
#       <th>OWNER</th>
#       <th>RENT_MIN</th>
#       <th>WOMEN</th>
#       <th>WATER</th>
#       <th>VIL_CODE</th>
#       <th>ELECT_D</th>
#       <th>MAT_IR_D</th>
#       <th>FAM_UP_D</th>
#       <th>ROOMS</th>
#       <th>SERV_H</th>
#       <th>BUSI_C</th>
#       <th>TOT_UNITS</th>
#       <th>EMPTY</th>
#       <th>HOUSEHOLD</th>
#       <th>MAT_M</th>
#       <th>SERVICE</th>
#       <th>DATE</th>
#       <th>FAM_SP_D</th>
#       <th>POP_D</th>
#       <th>MAT_BR</th>
#       <th>FAM_C</th>
#       <th>ELECT</th>
#       <th>BUSI_P</th>
#       <th>FAM_C_D</th>
#       <th>CHILD_D</th>
#       <th>NO_INFO</th>
#       <th>MAT_WOO</th>
#       <th>CHILD</th>
#       <th>FAMILIES</th>
# ...

# %%
display(HTML(df[df["STR_CODE"] == 'KIAS2S72S8'].to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MAT_WOO_D</th>
#       <th>FAM_S_D</th>
#       <th>RENT_STR</th>
#       <th>RENT_MEAN</th>
#       <th>BUSINESS</th>
#       <th>GEOMETRY</th>
#       <th>MAT_M_D</th>
#       <th>OWNER</th>
#       <th>RENT_MIN</th>
#       <th>WOMEN</th>
#       <th>WATER</th>
#       <th>VIL_CODE</th>
#       <th>ELECT_D</th>
#       <th>MAT_IR_D</th>
#       <th>FAM_UP_D</th>
#       <th>ROOMS</th>
#       <th>SERV_H</th>
#       <th>BUSI_C</th>
#       <th>TOT_UNITS</th>
#       <th>EMPTY</th>
#       <th>HOUSEHOLD</th>
#       <th>MAT_M</th>
#       <th>SERVICE</th>
#       <th>DATE</th>
#       <th>FAM_SP_D</th>
#       <th>POP_D</th>
#       <th>MAT_BR</th>
#       <th>FAM_C</th>
#       <th>ELECT</th>
#       <th>BUSI_P</th>
#       <th>FAM_C_D</th>
#       <th>CHILD_D</th>
#       <th>NO_INFO</th>
#       <th>MAT_WOO</th>
#       <th>CHILD</th>
#       <th>FAMILIES</th>
# ...

# %%
df_orp2 = df[(df["CHILD"]> 0) & (df["FAMILIES"] == 0)]
display(HTML(df_orp.to_html()))
    

import random
for row in df2.iterrows(): 
    rent_distro = []
    sd = (row[1]["RENT_MAX"] - row[1]["RENT_MIN"])/4
    for fam in range(int(row[1]["FAMILIES"])): 
        rent_distro.append(int(random.gauss(row[1]["RENT_MEAN"], sd)))
    print (rent_distro)
    
    
'''    
#for 0 rent to account for pay, computed from total rent means exlcuding zeros
if rent_mean == 0:
    rent_mean = 1122.8
if rent_mean == 1:
    rent_mean = 670
'''
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MAT_WOO_D</th>
#       <th>FAM_S_D</th>
#       <th>RENT_STR</th>
#       <th>RENT_MEAN</th>
#       <th>BUSINESS</th>
#       <th>GEOMETRY</th>
#       <th>MAT_M_D</th>
#       <th>OWNER</th>
#       <th>RENT_MIN</th>
#       <th>WOMEN</th>
#       <th>WATER</th>
#       <th>VIL_CODE</th>
#       <th>ELECT_D</th>
#       <th>MAT_IR_D</th>
#       <th>FAM_UP_D</th>
#       <th>ROOMS</th>
#       <th>SERV_H</th>
#       <th>BUSI_C</th>
#       <th>TOT_UNITS</th>
#       <th>EMPTY</th>
#       <th>HOUSEHOLD</th>
#       <th>MAT_M</th>
#       <th>SERVICE</th>
#       <th>DATE</th>
#       <th>FAM_SP_D</th>
#       <th>POP_D</th>
#       <th>MAT_BR</th>
#       <th>FAM_C</th>
#       <th>ELECT</th>
#       <th>BUSI_P</th>
#       <th>FAM_C_D</th>
#       <th>CHILD_D</th>
#       <th>NO_INFO</th>
#       <th>MAT_WOO</th>
#       <th>CHILD</th>
#       <th>FAMILIES</th>
# ...

# %%
df4 = df[df["STR_CODE"] == "KIAS2S72S8"]

# %%
display(HTML(df4.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MAT_WOO_D</th>
#       <th>FAM_S_D</th>
#       <th>RENT_STR</th>
#       <th>RENT_MEAN</th>
#       <th>BUSINESS</th>
#       <th>GEOMETRY</th>
#       <th>MAT_M_D</th>
#       <th>OWNER</th>
#       <th>RENT_MIN</th>
#       <th>WOMEN</th>
#       <th>WATER</th>
#       <th>VIL_CODE</th>
#       <th>ELECT_D</th>
#       <th>MAT_IR_D</th>
#       <th>FAM_UP_D</th>
#       <th>ROOMS</th>
#       <th>SERV_H</th>
#       <th>BUSI_C</th>
#       <th>TOT_UNITS</th>
#       <th>EMPTY</th>
#       <th>HOUSEHOLD</th>
#       <th>MAT_M</th>
#       <th>SERVICE</th>
#       <th>DATE</th>
#       <th>FAM_SP_D</th>
#       <th>POP_D</th>
#       <th>MAT_BR</th>
#       <th>FAM_C</th>
#       <th>ELECT</th>
#       <th>BUSI_P</th>
#       <th>FAM_C_D</th>
#       <th>CHILD_D</th>
#       <th>NO_INFO</th>
#       <th>MAT_WOO</th>
#       <th>CHILD</th>
#       <th>FAMILIES</th>
# ...
